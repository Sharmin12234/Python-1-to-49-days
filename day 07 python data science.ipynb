# %% [markdown]
# # If Elif Else conditional statement

# %%
x=50
y=100
if x>y:
 print('x is greather than y')
if y>x:
 print('y is greather than x')
 print('data science')
else:
    print('out1')
# Out:
# y is greather than x
# data science

# %%
Q8.Write a program to calculate the electricity bill (accept number of unit from user) according to
the following criteria
          unit                           Price
    
First 100 units                          no charge                       
Next 100 units                            Rs 5 per unit                        
After 200 units                           Rs 10 per unit (Extra 500 will be added) 
(For eample If input unit is 350 than total bill amount is Rs2000)

# %%
x=50
y=100
if x>y:
 print('x is greather than y')
elif y>x:
 print('y is greather than x')
 print('data science')
 if x != y:
  print('Not equal')
     
          
else:
    print('out1')
# Out:
# y is greather than x
# data science
# Not equal

# %% [markdown]
# # exercise divisable input check

# %%
num = float(input('Enter any number:'))
if num % 2 == 0:
    if num % 5 == 0:
        print(num.'Divisble bt 5 and 2')
        else:
            print('No 1')
else:
    print('No 2')
# Out:
#   Input In [4]
#     print(num.'Divisble bt 5 and 2')
#               ^
# SyntaxError: invalid syntax

# %%
num = float(input('Enter any number:'))

if num % 2 == 0:
    if num % 5 == 0:
        print(num,'Divisble bt 5 and 2')
    else:
      print('No 1')
else:
    print('No 2')
# Out:
# Enter any number:20
# 20.0 Divisble bt 5 and 2

# %%
Q8.Write a program to calculate the electricity bill (accept number of unit from user) according to
the following criteria
          unit                           Price
    
First 100 units                          no charge                       
Next 100 units                            Rs 5 per unit                        
After 200 units                           Rs 10 per unit (Extra 500 will be added) 
(For eample If input unit is 350 than total bill amount is Rs2000)

# %%
amount=0

net_units=float(input('Enter your unit value :'))

if net_units<=100;
    amount=0
    print('amount is ',amount)
elif net_units>100 and net_units<=200;
amount=(net_units-100)*5
print('amount is',amount
elif net_units>200:
amount=((net_units-299)*10+500)
      print('amount is',amount)
# Out:
#   Input In [1]
#     if net_units<=100;
#                      ^
# SyntaxError: invalid syntax
