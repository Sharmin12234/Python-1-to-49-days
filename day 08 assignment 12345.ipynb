# %%
from IPython.display import Image
Image('assignment1.png')

# %% [markdown]
# # Assignment 01:Solved
# Q:01.Take values of length and breadth of a rectangle from user and check if is sequare or not.

# %%
#Input the length from user
length = float(input('Enter the length:'))
#Input the breadth from user
breadth = float(input('Enter the breadth:'))
# Out:
# Enter the length:10
# Enter the breadth:10

# %%
#square is a rectangle whose length and breadth are equal and commonly called as sides which are of equal length.
if length == breadth :
    print('Yes, It is Square')
else:
     print('Yes, It is not Square')
# Out:
# Yes, It is Square

# %% [markdown]
# # or

# %%
#Input the length from user
length = float(input('Enter the length:'))
#Input the breadth from user
breadth = float(input('Enter the breadth:'))
# Out:
# Enter the length:10
# Enter the breadth:9

# %%
#square is a rectangle whose length and breadth are equal and commonly called as sides which are of equal length.
if length == breadth :
    print('Yes, It is  Square')
else:
     print('Yes, It is not Square')
# Out:
# Yes, It is not Square

# %% [markdown]
# # Assignment 02 : Solved
# Q:02 Take three int values from user and print greatest among them.

# %%
num1 = int(input('Enter first number:'))
num2 = int(input('Enter second number:'))
num3 = int(input('Enter third number:'))
if (num1>num2) and (num1>num3):
    largest = num1
elif
    (num2>num1) and (num2>num3):
        largest = num2
else:
    largest = num3
print('The largest number is',largest)
# Out:
#   Input In [2]
#     elif
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Assignment 03: Solved
# Q:03. A student will not be allowed to sit in exam if his/her attendence is less than 75%.

# %%
held = int(input('Number of classes held :'))
attended = int(input('Number of classes attended :'))
attended_ratio = (attended/held)*100
# Out:
# Number of classes held :20
# Number of classes attended :15

# %%
attended_ratio
# Out:
# 75.0

# %%
if attended_ratio >= 75:
    print('You are allowed')
else:
    print('You are not allowed')
# Out:
# You are not allowed

# %% [markdown]
# # or

# %%
held = int(input('Number of classes held :'))
attended = int(input('Number of classes attended :'))
attended_ratio = (attended/held)*100
# Out:
# Number of classes held :20
# Number of classes attended :14

# %%
attended_ratio
# Out:
# 70.0

# %%
if attended_ratio >= 75:
    print('You are allowed')
else: 
    print('You are not allowed')
# Out:
# You are not allowed
