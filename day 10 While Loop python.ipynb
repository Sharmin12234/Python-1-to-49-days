# %% [markdown]
# # While Loop

# %%
Syntax:
    while expression:
        statement(s)

# %%
Example:
    count = 0
    while(count<5):
        count = count+1
        print('Study Mart')

# %% [markdown]
# # while loop

# %%
i = 0
while (i<=10):
    print(i)
