# %% [markdown]
# # list in python

# %%
l1 = [2,5,8,10]
l1
# Out:
# [2, 5, 8, 10]

# %%
type(l1)
# Out:
# list

# %%
l1[0] #index
# Out:
# 2

# %%
l1[-1]
# Out:
# 10

# %%
l1[0:2]
# Out:
# [2, 5]

# %%
l1[0:3]
# Out:
# [2, 5, 8]

# %%
l1[0] = 'ai quest' #element change
l1
# Out:
# ['ai quest', 5, 8, 10]

# %%
l1
# Out:
# ['ai quest', 5, 8, 10]

# %%
l1.append('study mart') #element add
l1
# Out:
# ['ai quest', 5, 8, 10, 'study mart', 'study mart']

# %%
l1.append(5) #element add
l1
# Out:
# ['ai quest', 5, 8, 10, 'study mart', 'study mart', 5]

# %%
import sys
sys.getsizeof(l1)
# Out:
# 120

# %%
l1
# Out:
# ['ai quest', 5, 8, 10, 'study mart', 'study mart', 5]

# %%
l1.pop()
# Out:
# 5

# %%
l1
# Out:
# ['ai quest', 5, 8, 10, 'study mart', 'study mart']

# %%
l1.pop()
# Out:
# 'study mart'

# %%
l1
# Out:
# ['ai quest', 5, 8, 10, 'study mart']

# %%
l1.pop(0)
# Out:
# 'ai quest'

# %%
l1
# Out:
# [5, 8, 10, 'study mart']

# %%
#creating list using list constructor
l2 = list(('ai',12,(1,2,3,4)))
l2
# Out:
# ['ai', 12, (1, 2, 3, 4)]

# %%
type(l2)

# %%
l2[2]

# %%
#input list from user
l3 = []
n = int(input('Enter your total index:'))
for i in range (n):
    new = input()
    l3.append(new)
    print(l3)
