# %%
#input list from user
l3 = []
n = int(input('Enter your total index:'))
for i in range (n):
    new = input()
    l3.append(new)
    print(l3)
# Out:
# Enter your total index:3
# 1
# ['1']
# 2
# ['1', '2']
# 3
# ['1', '2', '3']

# %%
#input list from user
l3 = []
n = int(input('Enter your total index:'))
for i in range (n):
    new = input()
    l3.append(new)
print(l3) #final
# Out:
# Enter your total index:3
# 200
# 33
# 10
# ['200', '33', '10']

# %%
type(l3)
# Out:
# list

# %% [markdown]
# # list methods
# copy(),append(),extend(),insert(),index(),count(),sort(),reverse(),remove(),pop(),clear()

# %%
list1 = ['ai','ds','cs',150,20,True,[3,4],(1,2)]
list1
# Out:
# ['ai', 'ds', 'cs', 150, 20, True, [3, 4], (1, 2)]

# %%
list1[0]
# Out:
# 'ai'

# %%
list1[-1]
# Out:
# (1, 2)

# %%
list1[-1][0]
# Out:
# 1

# %% [markdown]
# # copy()

# %%
list2 = list1
list2
# Out:
# ['ai', 'ds', 'cs', 150, 20, True, [3, 4], (1, 2)]

# %%
list1
# Out:
# ['ai', 'ds', 'cs', 150, 20, True, [3, 4], (1, 2)]

# %%
list3 = list1.copy()
list3
# Out:
# ['ai', 'ds', 'cs', 150, 20, True, [3, 4], (1, 2)]

# %%
list1[0] = '1000'
list1
# Out:
# ['1000', 'ds', 'cs', 150, 20, True, [3, 4], (1, 2)]

# %%
list2
# Out:
# ['1000', 'ds', 'cs', 150, 20, True, [3, 4], (1, 2)]

# %%
list3
# Out:
# ['ai', 'ds', 'cs', 150, 20, True, [3, 4], (1, 2)]

# %%
list3[0] = 'data'
list3
# Out:
# ['data', 'ds', 'cs', 150, 20, True, [3, 4], (1, 2)]

# %% [markdown]
# # append()

# %%
list1.append(28)
list1
# Out:
# ['1000', 'ds', 'cs', 150, 20, True, [3, 4], (1, 2), 28]

# %%
l1 = [10,100,30]
l1
# Out:
# [10, 100, 30]

# %%
list1.append(l1)
list1
# Out:
# ['1000',
#  'ds',
#  'cs',
#  150,
#  20,
#  True,
#  [3, 4],
#  (1, 2),
#  28,
#  [10, 100, 30],
#  [10, 100, 30],
#  [10, 100, 30],
#  [10, 100, 30]]

# %%
list1[-1]
# Out:
# [10, 100, 30]

# %%
list1.append({1,2,3,4})
list1
# Out:
# ['1000',
#  'ds',
#  'cs',
#  150,
#  20,
#  True,
#  [3, 4],
#  (1, 2),
#  28,
#  [10, 100, 30],
#  [10, 100, 30],
#  [10, 100, 30],
#  [10, 100, 30],
#  {1, 2, 3, 4}]

# %%
list1[-1]
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# # extend()

# %%
list1.extend(l1)
list1
# Out:
# ['1000',
#  'ds',
#  'cs',
#  150,
#  20,
#  True,
#  [3, 4],
#  (1, 2),
#  28,
#  [10, 100, 30],
#  [10, 100, 30],
#  [10, 100, 30],
#  [10, 100, 30],
#  {1, 2, 3, 4},
#  10,
#  100,
#  30]

# %% [markdown]
# # insert()

# %%
list1.insert(0,'FAU')
list1
# Out:
# ['FAU',
#  '1000',
#  'ds',
#  'cs',
#  150,
#  20,
#  True,
#  [3, 4],
#  (1, 2),
#  28,
#  [10, 100, 30],
#  [10, 100, 30],
#  [10, 100, 30],
#  [10, 100, 30],
#  {1, 2, 3, 4},
#  10,
#  100,
#  30]

# %%
list1[0] = 'germary'
list1
# Out:
# ['germary',
#  '1000',
#  'ds',
#  'cs',
#  150,
#  20,
#  True,
#  [3, 4],
#  (1, 2),
#  28,
#  [10, 100, 30],
#  [10, 100, 30],
#  [10, 100, 30],
#  [10, 100, 30],
#  {1, 2, 3, 4},
#  10,
#  100,
#  30]

# %% [markdown]
# # index()

# %%
list1.index(150)
# Out:
# 4

# %%
list1.index({1,2,3,4})
# Out:
# 14

# %% [markdown]
# # count()

# %%
list1.count({1,2,3,4})
# Out:
# 1

# %%
list1.count(150)
# Out:
# 1

# %% [markdown]
# # sort()

# %%
ls2 = [10,2,6,7,9,100]

# %%
ls2.sort()
ls2
# Out:
# [2, 6, 7, 9, 10, 100]

# %% [markdown]
# # reverse()

# %%
ls2.reverse()
ls2
# Out:
# [100, 10, 9, 7, 6, 2]

# %% [markdown]
# # remove()

# %%
ls2.remove(100)
ls2
# Out:
# [10, 9, 7, 6, 2]

# %% [markdown]
# # pop()

# %%
ls2.pop(-1)
ls2
# Out:
# [10, 9, 7, 6]

# %%
ls2.clear()
ls2
# Out:
# []

# %%
ls3 = [1,g,fr]
