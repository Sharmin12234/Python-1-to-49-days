# %% [markdown]
# # set method

# %%
s1 = {1,2,3,4}
s2 = {1,4,'a','b'}
s1
# Out:
# {1, 2, 3, 4}

# %%
s2
# Out:
# {1, 4, 'a', 'b'}

# %%
s3 = frozenset(s2)
s3
# Out:
# frozenset({1, 4, 'a', 'b'})

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s1.add('d')
s1
# Out:
# {1, 2, 3, 4, 'd'}

# %%
s2 = s1

# %% [markdown]
# s2.remove('a')

# %%
s2
# Out:
# {1, 4, 'a', 'b'}
