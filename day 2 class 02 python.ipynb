# %% [markdown]
# # basic python

# %%
'data science'
# Out:
# 'data science'

# %% [markdown]
# output function /#print function

# %%
print('hello world', 'wellcome to 60 days of python02', sep='&', end='*')
# Out:
# hello world&wellcome to 60 days of python02*

# %% [markdown]
# # variables in python

# %%
var='hello world'
print(var)
# Out:
# hello world

# %%
print('var')
# Out:
# var

# %%
var='hello world'
print(var)
# Out:
# hello world

# %%
print('my sentence is  '+var)
# Out:
# my sentence is  hello world

# %%
var='hello world'
id(var)
# Out:
# 2373183278064

# %%
var='hello world'
import sys
sys.getsizeof(var)
# Out:
# 52

# %%
x=100

# %%
x
# Out:
# 100

# %%
y=100

# %%
y
# Out:
# 1000

# %%
id(x)
# Out:
# 140727910872600

# %%
id(y)
# Out:
# 1939841528240

# %%
x=1000

# %%
x
# Out:
# 100

# %%
y=1000

# %%
y
# Out:
# 1000

# %%
id(x)
# Out:
# 140727910872600

# %%
id(y)
# Out:
# 1939841528240

# %%
name='sharmin'
x='sharmin'
x
# Out:
# 'sharmin'

# %%
9var=100
# Out:
#   Cell In[7], line 1
#     9var=100
#     ^
# SyntaxError: invalid decimal literal

# %%
var9=100
var9
# Out:
# 100

# %%
var-2=100
# Out:
#   Cell In[9], line 1
#     var-2=100
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
10-2
# Out:
# 8

# %%
var_2=100
var_2
# Out:
# 100

# %%
x,y,z=10,100,1000
z
# Out:
# 1000

# %%
y
# Out:
# 100

# %%
x,y,z=10,100
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 x,y,z=10,100
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
x,y,z=10,100,0

# %%
x,y,z=10,100,'sharmin'
z
# Out:
# 'sharmin'

# %%
Var_2 # var_2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 Var_2
#
# NameError: name 'Var_2' is not defined

# %%
X=100
x=100
X
# Out:
# 100

# %%
x
# Out:
# 100

# %%
VARSITY=1001
varsity_id=1001
# Out:
# 1001

# %%
VARSITY
# Out:
# 1001

# %%
x=1000 #global
def func1():
    
x=500 #local
  print('my num is : ',x)
func1()
# Out:
#   Input In [4]
#     x=500 #local
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# input function class 03 /string

# %%
data="data science fun"
type (data)
# Out:
# str

# %%
data=input()

# %%
data
