# %% [markdown]
# # Array in python

# %%
import array as ar

# %%
ar1 = ar.array('i',[1,2,3,5,10])
ar1
# Out:
# array('i', [1, 2, 3, 5, 10])

# %%
type(ar1)
# Out:
# array.array

# %%
ar1 = ar.array('i',[1,2,3,5,10,2.9])
ar1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 ar1 = ar.array('i',[1,2,3,5,10,2.9])
#       2 ar1
#
# TypeError: integer argument expected, got float

# %%
ar1 = ar.array('f',[1,2,3,5,10,2.9])
ar1
# Out:
# array('f', [1.0, 2.0, 3.0, 5.0, 10.0, 2.9000000953674316])

# %%
ar1[0]
# Out:
# 1.0

# %%
ar1[0] = 15 #changeble

# %%
ar1
# Out:
# array('f', [15.0, 2.0, 3.0, 5.0, 10.0, 2.9000000953674316])

# %%
ar1[2:4]
# Out:
# array('f', [3.0, 5.0])

# %%
ar1.append(8)

# %%
ar1
# Out:
# array('f', [15.0, 2.0, 3.0, 5.0, 10.0, 2.9000000953674316, 8.0])

# %%
del ar1[-1]

# %%
ar1
# Out:
# array('f', [15.0, 2.0, 3.0, 5.0, 10.0, 2.9000000953674316])

# %%
len(ar1)
# Out:
# 6

# %%
ar1.reverse()

# %%
ar1
# Out:
# array('f', [2.9000000953674316, 10.0, 5.0, 3.0, 2.0, 15.0])

# %%
ar1.sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 ar1.sort()
#
# AttributeError: 'array.array' object has no attribute 'sort'

# %%
ar1.count(5)
# Out:
# 1

# %%
ar1.index(5.0)
# Out:
# 2

# %%
ar1.pop(4)
# Out:
# 15.0

# %%
ar1.remove(2)

# %%
ar1
# Out:
# array('f', [2.9000000953674316, 10.0, 3.0])

# %%
ar1.remove(10.0)

# %%
ar1
# Out:
# array('f', [2.9000000953674316, 3.0])

# %%
r = ar.array('i',[])
item = int(input())
for x in range(item):
    val = int(input())
    r.append(val)
print(val)
