# %% [markdown]
# # array in python

# %%
import array as ar

# %% [markdown]
# ar1 = ar.array('i',[1,2,4,6,10])

# %%
ar1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 ar1
#
# NameError: name 'ar1' is not defined
