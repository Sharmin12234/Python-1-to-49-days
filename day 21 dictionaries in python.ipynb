# %% [markdown]
# # dictionaries

# %%
dic = {
    'name': 'sharmin',
    'varsity' : 'Hub',
    
}

# %%
dic
# Out:
# {'name': 'sharmin', 'varsity': 'Hub'}

# %%
type(dic)
# Out:
# dict

# %%
dic.keys()
# Out:
# dict_keys(['name', 'varsity'])

# %%
dic.values()
# Out:
# dict_values(['sharmin', 'Hub'])

# %%
dic2 = dic

# %%
dic2
# Out:
# {'name': 'sharmin', 'varsity': 'Hub'}

# %%
dic2['school'] = 'KGHS'

# %%
dic2
# Out:
# {'name': 'sharmin', 'varsity': 'Hub', 'school': 'KGHS'}

# %%
dic
# Out:
# {'name': 'sharmin', 'varsity': 'Hub', 'school': 'KGHS'}

# %%
dic2 = dic.copy() #copy
dic2
# Out:
# {'name': 'sharmin', 'varsity': 'Hub', 'school': 'KGHS'}

# %%
dic['name'] = 'subha'

# %%
dic
# Out:
# {'name': 'subha', 'varsity': 'Hub', 'school': 'KGHS'}

# %%
dic2
# Out:
# {'name': 'sharmin', 'varsity': 'Hub', 'school': 'KGHS'}

# %%
dic['depart'] = 'data science'

# %%
dic
# Out:
# {'name': 'subha', 'varsity': 'Hub', 'school': 'KGHS', 'depart': 'data science'}

# %%
dic.update({'depart':'ai'})

# %%
dic
# Out:
# {'name': 'subha', 'varsity': 'Hub', 'school': 'KGHS', 'depart': 'ai'}

# %%
dic.popitem()
# Out:
# ('depart', 'ai')

# %%
dic
# Out:
# {'name': 'subha', 'varsity': 'Hub', 'school': 'KGHS'}

# %%
dic.pop('varsity')
# Out:
# 'Hub'

# %%
dic
# Out:
# {'name': 'subha', 'school': 'KGHS'}

# %%
del dic['school']

# %%
dic
# Out:
# {'name': 'subha'}

# %%
dic['depart'] = 'data science'

# %%
dic
# Out:
# {'name': 'subha', 'depart': 'data science'}

# %%
#print all items
for x in dic:
    print(dic[x]
# Out:
# name
# depart

# %%
for x in dic:
    print(dic[x])
# Out:
# subha
# data science

# %%
dic3 = list(dic.keys())

# %%
dic3
# Out:
# ['name', 'depart']

# %%
dic4 = list(dic.values())

# %%
dic4
# Out:
# ['subha', 'data science']

# %%
#dictionaries from user input
d = {}
y = int(input())
for x in range(y):
    key = input()
    value = input()
    print(d)

# %%
#dictionaries from user input
n = int(input())
d = {}
for i in range(n):
    key = input()
    value = input()
    print(d)
