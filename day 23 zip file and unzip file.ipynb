# %% [markdown]
# # zip file

# %%
import zipfile as zp
zipp = zp.ZipFile('zippe.zip','w')
zipp.write('picture.pdf')
zipp.write('picture.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [9], in <cell line: 3>()
#       1 import zipfile as zp
#       2 zipp = zp.ZipFile('zippe.zip','w')
# ----> 3 zipp.write('picture.pdf')
#       4 zipp.write('picture.png')
#
# File C:\ProgramData\Anaconda3\lib\zipfile.py:1736, in ZipFile.write(self, filename, arcname, compress_type, compresslevel)
#    1731 if self._writing:
#    1732     raise ValueError(
#    1733         "Can't write to ZIP archive while an open writing handle exists"
#    1734     )
# -> 1736 zinfo = ZipInfo.from_file(filename, arcname,
#    1737                           strict_timestamps=self._strict_timestamps)
#    1739 if zinfo.is_dir():
#    1740     zinfo.compress_size = 0
#
# File C:\ProgramData\Anaconda3\lib\zipfile.py:501, in ZipInfo.from_file(cls, filename, arcname, strict_timestamps)
#     499 if isinstance(filename, os.PathLike):
# ...

# %%
with zp.ZipFile('zipped.zip','r')
file.extractall('TEMP Unzip')
# Out:
#   Input In [10]
#     with zp.ZipFile('zipped.zip','r')
#                                      ^
# SyntaxError: invalid syntax
