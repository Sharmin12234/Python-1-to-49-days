# %% [markdown]
# # unpacking elements/ unzip

# %%
ids = (1,2,3)
name = ('subha','sadiya','tanjina')

# %%
zipped = tuple(zip(ids,name))
zipped
# Out:
# ((1, 'subha'), (2, 'sadiya'), (3, 'tanjina'))

# %%
ids,name = zip(*zipped)

# %%
ids
# Out:
# (1, 2, 3)

# %%
name
# Out:
# ('subha', 'sadiya', 'tanjina')

# %%
zipped
# Out:
# ((1, 'subha'), (2, 'sadiya'), (3, 'tanjina'))

# %%
zipped[0]
# Out:
# (1, 'subha')

# %%
ids,name = zipped[0]

# %%
ids
# Out:
# 1

# %%
name
# Out:
# 'subha'

# %%
zipped
# Out:
# ((1, 'subha'), (2, 'sadiya'), (3, 'tanjina'))

# %%
#unpacking using loop
for ids, name in zipped:
print(ids,name)
# Out:
#   Input In [67]
#     print(ids,name)
#     ^
# IndentationError: expected an indented block
