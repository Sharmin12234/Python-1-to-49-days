# %% [markdown]
# # continue statement

# %%
num = [1,2,3,4,5,6,7,8,14,15]
num
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 14, 15]

# %%
#list comprehension
[i for i in num if i%2 == 0]
# Out:
# [2, 4, 6, 8, 14]

# %%
for i in num:
    if i%2 == 1:
        continue
    print(i)
# Out:
# 2
# 4
# 6
# 8
# 14

# %%
sen = ' i love bangladesh and germani'

# %%
for i in sen.split():
    if i == 'and':
        continu

# %%
num = [1,2,3,4,5,6,7,8,14,15]
num
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 14, 15]

# %%
i = 0
while i<=num:
    if i%2 == 1:
        continue
    print(i)
    i = i+1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 2>()
#       1 i = 0
# ----> 2 while i<=num:
#       3     if i%2 == 1:
#       4         continue
#
# TypeError: '<=' not supported between instances of 'int' and 'list'
