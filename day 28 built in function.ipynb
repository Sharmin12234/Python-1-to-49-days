# %% [markdown]
# # commonly used built in functions

# %% [markdown]
# # 1.print():outputs text or variables to the console

# %%
print('data science!')
# Out:
# data science!

# %% [markdown]
# # 2.len():returns the length of an objects

# %%
my_list = [1,2,3,4,5]
length = len(my_list)

# %%
length
# Out:
# 5

# %% [markdown]
# # 3.input():reads input from the user

# %%
user_input = input('Enter something:')

# %% [markdown]
# # 4.type():returns the type of an object

# %%
x = 5
type_of_x = type(x)
type_of_x
