# %% [markdown]
# # 1.function definition

# %%
def depart1():
    print('data science')

# %%
depart1()
# Out:
# data science

# %% [markdown]
# # 2.function call

# %%
depart1()
# Out:
# data science

# %% [markdown]
# # 3.parameters

# %%
def depart2(name):
    print(f'my function {name}')

# %%
depart2('data science')
# Out:
# my function data science

# %% [markdown]
# # 4.return

# %%
def depart3():
    print('ai')
    return 1

# %%
depart3()
# Out:
# ai
# 1

# %%
def depart3():
    return print('ai')

# %%
depart3()
# Out:
# ai

# %%
def depart3():
    return depart()

# %%
depart3()
# Out:
# data science

# %% [markdown]
# # 1.question
# when a function that wont take any parameters explicity. instead.it defines local variables a and b within  the function and returns their sum. the values a and b are fixed within the function

# %%
def add():
    a = 10
    b = 20
    return a+b

# %%
add()
# Out:
# 30

# %%
def add():
    a = 10
    b = 20
    result = a+b
    return result

# %%
add()
# Out:
# 30

# %% [markdown]
# # 2.question
# when a function that will  take two parameters a and b and return sum. the values of a and b will not fixed  within the function

# %%
def add(a,b):
    return a+b

# %%
add(20,40)
# Out:
# 60

# %%
add(30,70)
# Out:
# 100

# %%
def add(a,b):
    result = a+b
    return result

# %%
add(20,7)
# Out:
# 27
