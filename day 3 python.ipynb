# %%
data="data science fun"
type(data)
# Out:
# str

# %%
data=input()
# Out:
#  data science fun!

# %%
data
# Out:
# 'data science fun!'

# %%
type(data)
# Out:
# str

# %%
x=input()
y=input()
# Out:
#  10
#  20

# %%
x+y
# Out:
# '1020'

# %%
x=10
y=20

# %%
x=int(x)
y=int(y)
x+y
# Out:
# 30

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# int

# %%
x=int(input("Enter yuor 1st num : "))
# Out:
# Enter yuor 1st num :  200

# %%
x
# Out:
# 200

# %%
y

# %%
y=float(input("Enter yuor 2st num : "))
# Out:
# Enter yuor 2st num :  10.5

# %%
x+y
# Out:
# 210.5

# %%
data="60 Days of python"

# %%
type(data)
# Out:
# str

# %%
len(data)
# Out:
# 17

# %%
import sys
sys.getsizeof(data)
# Out:
# 58

# %%
data.count("python")
# Out:
# 0

# %%
sub="days of"
data.count(sub)
# Out:
# 0

# %% [markdown]
# # python string method

# %%
data="60 Days of python"

# %%
data.find("f") #find value from string
# Out:
# 9

# %%
data.find('y',6,10)
# Out:
# -1

# %%
data="60 Days of python"
data.find('y',6,14)
# Out:
# 12

# %%
data.index('y')
# Out:
# 5

# %%
data.index('y',6,13)
# Out:
# 12

# %%
data.index('y',6,10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 data.index('y',6,10)
#
# ValueError: substring not found

# %%
data.lower() #convert all char into lower case
# Out:
# '60 days of python'

# %%
data.upper() #convert all char into upper case
# Out:
# '60 DAYS OF PYTHON'

# %%
data.casefold() #lower
# Out:
# '60 days of python'

# %%
x='data SCIENCE is fun'
# Out:
# <function str.capitalize()>

# %%
x.capitalize()
# Out:
# 'Data science is fun'

# %%
x.swapcase()
# Out:
# 'DATA science IS FUN'

# %%
x.title()
# Out:
# 'Data Science Is Fun'

# %%
x.islower()
# Out:
# False

# %%
x.isupper()
# Out:
# False

# %%
x.isdigit()
# Out:
# False

# %%
x.encode()
# Out:
# b'data SCIENCE is fun'

# %%
type(x.encode())
# Out:
# bytes

# %%
x.split()
# Out:
# ['data', 'SCIENCE', 'is', 'fun']

# %%
x.split()[0]
# Out:
# 'data'

# %%
x.split()[1]
# Out:
# 'SCIENCE'

# %%
x='data SCIENCE is fun'
x.center(100)
# Out:
# '                                        data SCIENCE is fun                                         '

# %%
x.replace('data','AI')
# Out:
# 'AI SCIENCE is fun'

# %%
x=10
y=100
z=x*y
print('I have ',z,'taka')
# Out:
# I have  1000 taka

# %%
print('I have () taka',format(z))
# Out:
# I have () taka 1000
