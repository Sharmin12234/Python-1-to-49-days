# %% [markdown]
# # more about return

# %%
def u_in():
    x1 = int(input())
    x2 = int(input())
    y1 = int(input())
    y2 = int(input())
    return x1,x2

# %%
u_in()
# Out:
# 1
# 2
# 3
# 4
# (1, 2)

# %%
def u_in():
    x1 = int(input())
    x2 = int(input())
    y1 = int(input())
    y2 = int(input())
    return x1,x2,y1,y2

# %%
u_in()
# Out:
# 1
# 2
# 3
# 4
# (1, 2, 3, 4)

# %%
def u_in():
    x1 = int(input())
    x2 = int(input())
    y1 = int(input())
    y2 = int(input())
    return x1,y1,x2,y2

# %%
u_in()
# Out:
# 1
# 2
# 3
# 4
# (1, 3, 2, 4)

# %%
def u_in():
    x1 = int(input())
    x2 = int(input())
    y1 = int(input())
    y2 = int(input())
    return (x1,y1),(x2,y2)

# %%
u_in()
# Out:
# 1
# 2
# 3
# 4
# ((1, 3), (2, 4))

# %%
def u_in():
    x1 = int(input())
    x2 = int(input())
    y1 = int(input())
    y2 = int(input())
    return (x1,y1),(x2,y2)

# %%
r1, r2 = u_in()
# Out:
# 1
# 2
# 3
# 4

# %%
r1
# Out:
# (1, 3)

# %%
r2
# Out:
# (2, 4)

# %%
r1,_ = u_in()
