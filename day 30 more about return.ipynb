# %% [markdown]
# # more about return

# %%
def u_in():
    x1 = int(input())
    x2 = int(input())
    y1 = int(input())
    y2 = int(input())
    return x1,x2

# %%
u_in()

# %%
def u_in():
    x1 = int(input())
    x2 = int(input())
    y1 = int(input())
    y2 = int(input())
    return x1,x2,y1,y2

# %%
u_in()

# %%
def u_in():
    x1 = int(input())
    x2 = int(input())
    y1 = int(input())
    y2 = int(input())
    return x1,y1,x2,y2

# %%
u_in()

# %%
def u_in():
    x1 = int(input())
    x2 = int(input())
    y1 = int(input())
    y2 = int(input())
    return x1,y1,x2,y2

# %%
def u_in():
    x1 = int(input())
    x2 = int(input())
    y1 = int(input())
    y2 = int(input())
    return (x1,y1),(x2,y2)

# %%
u_in()
