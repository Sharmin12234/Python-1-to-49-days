# %% [markdown]
# # return

# %%
def u_in():
    x1 = int(input())
    x2 = int(input())
    y1 = int(input())
    y2 = int(input())
    return (x1,y1),(x2,y2)

# %%
r1, r2 = u_in()
# Out:
# 1
# 2
# 3
# 4

# %%
r1

# %% [markdown]
# r2

# %% [markdown]
# r1,_ = u_in

# %%
r1 = u_in()
