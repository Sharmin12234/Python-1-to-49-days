# %% [markdown]
# # more about return

# %%
def u_in():
    x1 = int(input())
    x2 = int(input())
    y1 = int(input())
    y2 = int(input())
    return (x1,y1),(x2,y2)

# %%
r1, r2 = u_in()
# Out:
# 1
# 2
# 3
# 4

# %%
r1
# Out:
# (1, 3)

# %%
r2
# Out:
# (2, 4)

# %%
r1,_ = u_in()
# Out:
# 1
# 2
# 3
# 4

# %%
r1
# Out:
# (1, 3)

# %%
def sq_cube(x):
    sq = x**2
    cube = x**3
    return sq,cube

# %%
sq_cube(3)
# Out:
# (9, 27)

# %%
def mulp():
    x = int(input('x = '))
    y = int(input('y = '))
    result = x*y
    print(result)
