# %%
def remove_duplicates(input_list):
    unique_list = [] 
    
    for item in input_list:
        if item not in unique_list:
            unique_list.append(item)
            
        return unique_list

# %%
input_list = [1,2,2,3,4,5,6,6,7,8,9,]
remove_duplicates(input_list)
    
print(f'real list {input_list}')
print(f'unique list {remove_duplicates(input_list)}')
# Out:
# real list [1, 2, 2, 3, 4, 5, 6, 6, 7, 8, 9]
# unique list [1]

# %%
def double_element(input_list):
    double_list = [x*2 for x in input_list] 
    return double_list
input_list = [1,2,2,3,4,5,6,6,7,8,9]
double_element(input_list)
# Out:
# [2, 4, 4, 6, 8, 10, 12, 12, 14, 16, 18]
