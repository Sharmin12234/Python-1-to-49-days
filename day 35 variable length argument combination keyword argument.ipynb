# %% [markdown]
# # variable length argument combination keyword argument

# %%
name : sharmin subha
unvarsity : hub
city :dhaka

# %%
def per_inf(name,*arg):
    print(name)
    print(arg)
    print(type(arg))
    
per_inf('sharmin subha','hub','dhaka')
# Out:
# sharmin subha
# ('hub', 'dhaka')
# <class 'tuple'>

# %%
def per_inf(name,**arg):
    print(name)
    print(arg)
    print(type(arg))
    
per_inf(city = 'dhaka',name = 'sharmin subha',varsity = 'hub')
# Out:
# sharmin subha
# {'city': 'dhaka', 'varsity': 'hub'}
# <class 'dict'>
