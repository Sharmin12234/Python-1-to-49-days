# %% [markdown]
# # recursion

# %%
#5! = 5*4*3*2*1
def fact(x):
    if x==0:
        return 1
    return x*fact(x-1)

# %%
fact(0)
# Out:
# 1

# %%
#5! = 5*4*3*2*1
def fact(x):
    if x==0:
        return 1
    return x*fact(x-1)

# %%
fact(5)
# Out:
# 120

# %%
def depart():
    print('ai')
    depart()

# %%
depart()
# Out:
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ai
# ...

# %%
import sys
sys.getrecursionlimit()
# Out:
# 3000
