# %%
import test_module
test_module.greet('subha')
test_module.sequare(10)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 import test_module
#       2 test_module.greet('subha')
#       3 test_module.sequare(10)
#
# ModuleNotFoundError: No module named 'test_module'

# %%
from test_module import greet,sequare
greet('subha')
sequare(10)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 from test_module import greet,sequare
#       2 greet('subha')
#       3 sequare(10)
#
# ModuleNotFoundError: No module named 'test_module'

# %%
from test_module import*
greet('subha')
sequare(10)
