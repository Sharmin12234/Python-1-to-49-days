# %%
# !pip install  pypdf
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pypdf
#   Downloading pypdf-5.4.0-py3-none-any.whl (302 kB)
# Requirement already satisfied: typing_extensions>=4.0 in c:\programdata\anaconda3\lib\site-packages (from pypdf) (4.1.1)
# Installing collected packages: pypdf
# Successfully installed pypdf-5.4.0

# %%
from pypdf import PdfReader

# %%
pdf = PdfReader('1-Symbol-Table.pdf')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 pdf = PdfReader('1-Symbol-Table.pdf')
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pypdf\_reader.py:136, in PdfReader.__init__(self, stream, strict, password)
#     132 self._page_id2num: Optional[Dict[Any, Any]] = None
#     134 self._validated_root: Optional[DictionaryObject] = None
# --> 136 self._initialize_stream(stream)
#     137 self._known_objects: Set[Tuple[int, int]] = set()
#     139 self._override_encryption = False
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pypdf\_reader.py:155, in PdfReader._initialize_stream(self, stream)
#     153 self._stream_opened = False
#     154 if isinstance(stream, (str, Path)):
# --> 155     with open(stream, "rb") as fh:
#     156         stream = BytesIO(fh.read())
#     157     self._stream_opened = True
#
# FileNotFoundError: [Errno 2] No such file or directory: '1-Symbol-Table.pdf'

# %%
len(pdf.pages)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 len(pdf.pages)
#
# NameError: name 'pdf' is not defined

# %%
page = pdf.page[1]
page.extract_text()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 page = pdf.page[1]
#       2 page.extract_text()
#
# NameError: name 'pdf' is not defined

# %%
import PyPDF2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 import PyPDF2
#
# ModuleNotFoundError: No module named 'PyPDF2'

# %%
path = '1-Symbpl-Table.pdf'
with open(path, 'rb') as file:
    reader = PyPDF2.PdfReader(file)
    
    first_page = reader.pages[1].extract_text()
    print(first_page)

# %%
import PyPDF2

# %%
path = '1-Symbpl-Table.pdf'
with open(path, 'rb') as file:
    reader = PyPDF2.PdfReader(file)
    for page in reader page!
    text = page.extract_text()
    print(text)
    print('\n')
