# %% [markdown]
# # module

# %%
# %%writwfile test_module.py
# def greet(name):
#     print(f'hello {name}')
#
# def sequare(x):
#     return x**2
# Out:
# UsageError: Cell magic `%%writwfile` not found.
