# %%
data="data science fun"
type(data)
# Out:
# str

# %%
data=input()
# Out:
#  data science fun!

# %%
data
# Out:
# 'data science fun!'

# %%
type(data)
# Out:
# str

# %%
x=input()
y=input()
# Out:
#  10
#  20

# %%
x+y
# Out:
# '1020'

# %%
type(x)
# Out:
# str

# %%
type(y)
# Out:
# str
